# %% [markdown]
# # Multi-Cohort EDA v2
#
# This notebook wraps the rebuilt multi-cohort EDA runner. It follows the repository convention `base_files/<cohort>/responses<stage>.csv`, derives `cohort` and `stage` during load, and writes outputs to `EDA/eda_outputs_multi_cohort_v2`.

# %%
# %run ./generative_ai_software_engineering_eda_multi_cohort_v2.py
# Out:
# Git sync: ok
# Loaded 4 source file(s)
# Raw shape: 149 rows x 57 columns
#    cohort  stage       file_name  \
# 0  2025.2      1  responses1.csv
# 1  2025.2      2  responses2.csv
# 2  2025.2      3  responses3.csv
# 3  2026.1      1  responses1.csv
#
#                                        relative_path  n_rows  n_columns
# 0  /home/amg/projects/uece/extensao3/extensao3-an...      46         49
# 1  /home/amg/projects/uece/extensao3/extensao3-an...      41         48
# 2  /home/amg/projects/uece/extensao3/extensao3-an...      40         48
# 3  /home/amg/projects/uece/extensao3/extensao3-an...      22         49
#                                                column    dtype  missing_pct
# 0                                           Timestamp      str         0.00
# 1   Em qual semestre do curso de Engenharia de Sof...      str        54.36
# 2                     Você já possui outra graduação?      str         0.00
# 3                          Qual é a sua faixa etária?      str         0.00
# 4                                Qual é o seu gênero?      str         0.00
# ..                                                ...      ...          ...
# 61                                           likert_4    int64         0.00
# 62                                           likert_5    int64         0.00
# 63                                           likert_6    int64         0.00
# 64                                           likert_7    int64         0.00
# 65                                   perception_index  float64         0.00
#
# [66 rows x 3 columns]
#    cohort  stage  n_responses
# 0  2025.2      1           46
# 1  2025.2      2           41
# 2  2025.2      3           40
# 3  2026.1      1           22
# Com que frequência você utiliza ferramentas de IA generativa em seu dia a dia de maneira geral?  Algumas vezes por mês  \
# row_0
# 2025.2 | stage 1                                                                                                  23.9
# 2025.2 | stage 2                                                                                                  14.6
# 2025.2 | stage 3                                                                                                   7.5
# 2026.1 | stage 1                                                                                                  22.7
#
# Com que frequência você utiliza ferramentas de IA generativa em seu dia a dia de maneira geral?  Diariamente  \
# row_0
# 2025.2 | stage 1                                                                                        41.3
# 2025.2 | stage 2                                                                                        46.3
# 2025.2 | stage 3                                                                                        45.0
# 2026.1 | stage 1                                                                                        54.5
#
# Com que frequência você utiliza ferramentas de IA generativa em seu dia a dia de maneira geral?  Nunca  \
# row_0
# 2025.2 | stage 1                                                                                   2.2
# 2025.2 | stage 2                                                                                   0.0
# 2025.2 | stage 3                                                                                   0.0
# 2026.1 | stage 1                                                                                   4.5
#
# Com que frequência você utiliza ferramentas de IA generativa em seu dia a dia de maneira geral?  Raramente  \
# row_0
# 2025.2 | stage 1                                                                                       4.3
# 2025.2 | stage 2                                                                                       0.0
# 2025.2 | stage 3                                                                                       2.5
# 2026.1 | stage 1                                                                                       0.0
#
# Com que frequência você utiliza ferramentas de IA generativa em seu dia a dia de maneira geral?  Semanalmente
# row_0
# 2025.2 | stage 1                                                                                         28.3
# 2025.2 | stage 2                                                                                         39.0
# 2025.2 | stage 3                                                                                         45.0
# 2026.1 | stage 1                                                                                         18.2
#                                                 item      mean
# 0  Avalie seu nível de concordância com as afirma...  4.510067
# 1  Avalie seu nível de concordância com as afirma...  4.302013
# 6  Avalie seu nível de concordância com as afirma...  4.161074
# 5  Avalie seu nível de concordância com as afirma...  3.812081
# 3  Avalie seu nível de concordância com as afirma...  3.664430
# 7  Avalie seu nível de concordância com as afirma...  3.624161
# 2  Avalie seu nível de concordância com as afirma...  3.489933
# 4  Avalie seu nível de concordância com as afirma...  3.442953
#    cohort  stage  count      mean  median
# 0  2025.2      1     46  3.940217  3.8125
# 1  2025.2      2     41  3.871951  3.8750
# 2  2025.2      3     40  3.887500  3.8750
# 3  2026.1      1     22  3.727273  3.7500
#           test            x                 y         stat       p_value  \
# 0     spearman  general_num  perception_index     0.457985  4.285361e-09
# 1     spearman       se_num  perception_index     0.420343  9.446061e-08
# 2  mannwhitney       cohort  perception_index  1586.000000  3.114626e-01
# 3      kruskal        stage  perception_index     0.272885  8.724566e-01
#
#        n
# 0  149.0
# 1  149.0
# 2    NaN
# 3    NaN
# Outputs written to /home/amg/projects/uece/extensao3/extensao3-analytics/EDA/eda_outputs_multi_cohort_v2
